# %%
 pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from torch)
#   Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torch) (4.13.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch)
#   Downloading https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torchvision) (1.22.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torchvision) (11.1.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 6.3 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-manylinux_2_28_x86_64.whl (176.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 MB 16.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-manylinux_2_28_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.5 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.8 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 13.7 MB/s eta 0:00:0031m14.6 MB/s eta 0:00:01
# Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.9 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision, torchaudio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [torchaudio]0m  9/10 [torchaudio]]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.3.126 requires ultralytics-thop>=2.0.0, which is not installed.
# ultralytics 8.3.126 requires numpy>=1.23.0, but you have numpy 1.22.3 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 filelock-3.13.1 fsspec-2024.6.1 jinja2-3.1.4 mpmath-1.3.0 networkx-3.3 sympy-1.13.3 torch-2.7.0+cpu torchaudio-2.7.0+cpu torchvision-0.22.0+cpu
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install --upgrade ultralytics
# Out:
# Requirement already satisfied: ultralytics in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (8.3.126)
# Collecting numpy>=1.23.0 (from ultralytics)
#   Downloading numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (3.5.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (4.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (1.8.1)
# Requirement already satisfied: torch>=1.8.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (2.7.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (0.22.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (5.9.1)
# Requirement already satisfied: py-cpuinfo in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (1.4.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: cycler>=0.10 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Collecting numpy>=1.23.0 (from ultralytics)
#   Using cached numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fx/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 6.5 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: numpy, ultralytics-thop
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.3
#     Uninstalling numpy-1.22.3:
#       Successfully uninstalled numpy-1.22.3━━━━━━━━━━━ 0/2 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ultralytics-thop]1/2 [ultralytics-thop]
# Successfully installed numpy-1.24.4 ultralytics-thop-2.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

from ultralytics import solutions

# %%
# cap = cv2.VideoCapture("test1.mp4")
cap = cv2.VideoCapture(0)

assert cap.isOpened(), "Error reading video file"

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
# video_writer = cv2.VideoWriter("isegment_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize instance segmentation object
isegment = solutions.InstanceSegmentation(
    show=True,  # display the output
    model="yolo11n-seg.pt",  #nano
    # model="yolo11m-seg.pt" #medium
    classes=[0],  # segment specific classes i.e, person (0) and car (2) with pretrained model.
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = isegment(im0)

    # print(results)  # access the output

    # video_writer.write(results.plot_im)  # write the processed frame.

cap.release()
# video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo11n-seg.pt', 'classes': [0], 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True}
# [ WARN:0@6.530] global cap_gstreamer.cpp:1173 isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-seg.pt to 'yolo11n-seg.pt'...
# 100%|██████████| 5.90M/5.90M [00:00<00:00, 20.5MB/s]
# 0: 480x640 2 persons, 377.4ms
# Speed: 6.7ms preprocess, 377.4ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 480x640 1 person, 444.6ms
# Speed: 4.7ms preprocess, 444.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 2 persons, 635.4ms
# Speed: 3.9ms preprocess, 635.4ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 480x640 2 persons, 379.6ms
# Speed: 2.3ms preprocess, 379.6ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 480x640 1 person, 418.7ms
# Speed: 2.1ms preprocess, 418.7ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 428.9ms
# Speed: 4.7ms preprocess, 428.9ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 346.2ms
# Speed: 2.2ms preprocess, 346.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 683.0ms
# Speed: 15.1ms preprocess, 683.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 2 persons, 789.1ms
# Speed: 3.7ms preprocess, 789.1ms inference, 12.2ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 480x640 1 person, 377.2ms
# Speed: 10.6ms preprocess, 377.2ms inference, 27.6ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 566.2ms
# Speed: 4.0ms preprocess, 566.2ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 2811.4ms
# Speed: 3.9ms preprocess, 2811.4ms inference, 67.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 881.4ms
# Speed: 24.0ms preprocess, 881.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 379.7ms
# Speed: 3.4ms preprocess, 379.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 295.9ms
# Speed: 6.4ms preprocess, 295.9ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 419.0ms
# Speed: 6.9ms preprocess, 419.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 308.1ms
# Speed: 7.7ms preprocess, 308.1ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 285.4ms
# Speed: 6.3ms preprocess, 285.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 284.6ms
# Speed: 2.6ms preprocess, 284.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 632.2ms
# Speed: 2.3ms preprocess, 632.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 904.9ms
# Speed: 8.2ms preprocess, 904.9ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 903.2ms
# Speed: 19.8ms preprocess, 903.2ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 782.5ms
# Speed: 26.3ms preprocess, 782.5ms inference, 21.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 299.9ms
# Speed: 4.3ms preprocess, 299.9ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 273.5ms
# Speed: 2.6ms preprocess, 273.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 264.4ms
# Speed: 7.2ms preprocess, 264.4ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 279.7ms
# Speed: 2.3ms preprocess, 279.7ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 480x640 1 person, 334.0ms
# Speed: 2.2ms preprocess, 334.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 340.6ms
# Speed: 2.0ms preprocess, 340.6ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 480x640 1 person, 635.2ms
# Speed: 4.6ms preprocess, 635.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 445.5ms
# Speed: 2.5ms preprocess, 445.5ms inference, 16.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 464.2ms
# Speed: 2.4ms preprocess, 464.2ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 (no detections), 504.6ms
# Speed: 27.8ms preprocess, 504.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# WARNING ⚠️ no tracks found!
# WARNING ⚠️ No masks detected! Ensure you're using a supported Ultralytics segmentation model.
# 🚀 Results: SolutionResults()
#
# 0: 480x640 1 person, 665.9ms
# Speed: 11.0ms preprocess, 665.9ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 422.6ms
# Speed: 6.9ms preprocess, 422.6ms inference, 18.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 467.6ms
# Speed: 2.4ms preprocess, 467.6ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 382.0ms
# Speed: 11.9ms preprocess, 382.0ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 465.7ms
# Speed: 2.7ms preprocess, 465.7ms inference, 32.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 657.0ms
# Speed: 14.6ms preprocess, 657.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 565.2ms
# Speed: 8.3ms preprocess, 565.2ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 610.0ms
# Speed: 14.1ms preprocess, 610.0ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 439.5ms
# Speed: 2.9ms preprocess, 439.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 249.3ms
# Speed: 2.6ms preprocess, 249.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 244.1ms
# Speed: 2.4ms preprocess, 244.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 624.6ms
# Speed: 14.5ms preprocess, 624.6ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 284.0ms
# Speed: 1.8ms preprocess, 284.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 251.7ms
# Speed: 6.0ms preprocess, 251.7ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 559.8ms
# Speed: 2.5ms preprocess, 559.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 480x640 1 person, 315.4ms
# Speed: 8.3ms preprocess, 315.4ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 355.9ms
# Speed: 2.3ms preprocess, 355.9ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 314.3ms
# Speed: 2.3ms preprocess, 314.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 282.0ms
# Speed: 2.2ms preprocess, 282.0ms inference, 12.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 283.6ms
# Speed: 3.9ms preprocess, 283.6ms inference, 14.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 284.4ms
# Speed: 3.0ms preprocess, 284.4ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 435.3ms
# Speed: 1.8ms preprocess, 435.3ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 249.9ms
# Speed: 3.5ms preprocess, 249.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 278.9ms
# Speed: 2.4ms preprocess, 278.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 235.4ms
# Speed: 4.7ms preprocess, 235.4ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 368.6ms
# Speed: 11.9ms preprocess, 368.6ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 279.6ms
# Speed: 2.8ms preprocess, 279.6ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 347.3ms
# Speed: 3.9ms preprocess, 347.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 467.6ms
# Speed: 4.0ms preprocess, 467.6ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 250.9ms
# Speed: 6.5ms preprocess, 250.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 276.9ms
# Speed: 5.7ms preprocess, 276.9ms inference, 11.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 279.3ms
# Speed: 10.6ms preprocess, 279.3ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 274.9ms
# Speed: 4.7ms preprocess, 274.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 261.4ms
# Speed: 6.0ms preprocess, 261.4ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 300.7ms
# Speed: 2.1ms preprocess, 300.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 287.3ms
# Speed: 2.4ms preprocess, 287.3ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 241.5ms
# Speed: 4.1ms preprocess, 241.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 251.2ms
# Speed: 2.2ms preprocess, 251.2ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 272.9ms
# Speed: 5.6ms preprocess, 272.9ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 285.9ms
# Speed: 3.4ms preprocess, 285.9ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 262.8ms
# Speed: 2.4ms preprocess, 262.8ms inference, 13.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 436.9ms
# Speed: 15.4ms preprocess, 436.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 260.6ms
# Speed: 2.6ms preprocess, 260.6ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 264.8ms
# Speed: 5.4ms preprocess, 264.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 266.1ms
# Speed: 2.3ms preprocess, 266.1ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 248.8ms
# Speed: 2.8ms preprocess, 248.8ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 280.2ms
# Speed: 2.2ms preprocess, 280.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 1607.4ms
# Speed: 10.5ms preprocess, 1607.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 511.5ms
# Speed: 5.6ms preprocess, 511.5ms inference, 32.0ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 400.2ms
# Speed: 4.0ms preprocess, 400.2ms inference, 26.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 1746.2ms
# Speed: 5.0ms preprocess, 1746.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 554.2ms
# Speed: 17.2ms preprocess, 554.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 503.2ms
# Speed: 9.9ms preprocess, 503.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 620.1ms
# Speed: 3.5ms preprocess, 620.1ms inference, 13.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 369.0ms
# Speed: 2.4ms preprocess, 369.0ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 314.3ms
# Speed: 19.4ms preprocess, 314.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 380.2ms
# Speed: 16.9ms preprocess, 380.2ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 315.2ms
# Speed: 3.3ms preprocess, 315.2ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 913.5ms
# Speed: 8.6ms preprocess, 913.5ms inference, 16.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 601.1ms
# Speed: 5.0ms preprocess, 601.1ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 642.2ms
# Speed: 10.2ms preprocess, 642.2ms inference, 21.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 1364.6ms
# Speed: 6.2ms preprocess, 1364.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 308.9ms
# Speed: 4.7ms preprocess, 308.9ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 301.5ms
# Speed: 2.8ms preprocess, 301.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 290.5ms
# Speed: 1.9ms preprocess, 290.5ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 255.5ms
# Speed: 2.7ms preprocess, 255.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 343.4ms
# Speed: 2.1ms preprocess, 343.4ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 364.1ms
# Speed: 4.1ms preprocess, 364.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 341.7ms
# Speed: 4.1ms preprocess, 341.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 296.0ms
# Speed: 2.9ms preprocess, 296.0ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 403.0ms
# Speed: 3.1ms preprocess, 403.0ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 276.2ms
# Speed: 2.6ms preprocess, 276.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 238.8ms
# Speed: 3.9ms preprocess, 238.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 480x640 1 person, 338.5ms
# Speed: 3.8ms preprocess, 338.5ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 25
#      22         print("Video frame is empty or video processing has been successfully completed.")
#      23         break
# ---> 25     results = isegment(im0)
#      27     # print(results)  # access the output
#      28
#      29     # video_writer.write(results.plot_im)  # write the processed frame.
#      31 cap.release()
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/solutions/solutions.py:214, in BaseSolution.__call__(self, *args, **kwargs)
#     212 def __call__(self, *args, **kwargs):
#     213     """Allow instances to be called like a function with flexible arguments."""
# --> 214     result = self.process(*args, **kwargs)  # Call the subclass-specific process method
#     215     if self.CFG["verbose"]:  # extract verbose value to display the output logs if True
#     216         LOGGER.info(f"🚀 Results: {result}")
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/solutions/instance_segmentation.py:64, in InstanceSegmentation.process(self, im0)
#      48 def process(self, im0):
#      49     """
#      50     Perform instance segmentation on the input image and annotate the results.
#      51
#    (...)
#      62         >>> print(summary)
#      63     """
# ---> 64     self.extract_tracks(im0)  # Extract tracks (bounding boxes, classes, and masks)
#      66     # Iterate over detected classes, track IDs, and segmentation masks
#      67     if self.masks is None:
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/solutions/solutions.py:138, in BaseSolution.extract_tracks(self, im0)
#     126 def extract_tracks(self, im0):
#     127     """
#     128     Applies object tracking and extracts tracks from an input image or frame.
#     129
#    (...)
#     136         >>> solution.extract_tracks(frame)
#     137     """
# --> 138     self.tracks = self.model.track(source=im0, persist=True, classes=self.classes, **self.track_add_args)
#     139     self.track_data = self.tracks[0].obb or self.tracks[0].boxes  # Extract tracks for OBB or object detection
#     141     self.masks = (
#     142         self.tracks[0].masks if hasattr(self.tracks[0], "masks") and self.tracks[0].masks is not None else None
#     143     )
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/engine/model.py:596, in Model.track(self, source, stream, persist, **kwargs)
#     594 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     595 kwargs["mode"] = "track"
# --> 596 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/engine/model.py:552, in Model.predict(self, source, stream, predictor, **kwargs)
#     550 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     551     self.predictor.set_prompts(prompts)
# --> 552 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/engine/predictor.py:218, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     216     return self.stream_inference(source, model, *args, **kwargs)
#     217 else:
# --> 218     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/engine/predictor.py:329, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     327 # Inference
#     328 with profilers[1]:
# --> 329     preds = self.inference(im, *args, **kwargs)
#     330     if self.args.embed:
#     331         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/engine/predictor.py:173, in BasePredictor.inference(self, im, *args, **kwargs)
#     167 """Run inference on a given image using the specified model and arguments."""
#     168 visualize = (
#     169     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     170     if self.args.visualize and (not self.source_type.tensor)
#     171     else False
#     172 )
# --> 173 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:592, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     590 # PyTorch
#     591 if self.pt or self.nn_module:
# --> 592     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     594 # TorchScript
#     595 elif self.jit:
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/nn/tasks.py:115, in BaseModel.forward(self, x, *args, **kwargs)
#     113 if isinstance(x, dict):  # for cases of training and validating while training.
#     114     return self.loss(x, *args, **kwargs)
# --> 115 return self.predict(x, *args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/nn/tasks.py:133, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     131 if augment:
#     132     return self._predict_augment(x)
# --> 133 return self._predict_once(x, profile, visualize, embed)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/nn/tasks.py:154, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     152 if profile:
#     153     self._profile_one_layer(m, x, dt)
# --> 154 x = m(x)  # run
#     155 y.append(x if m.i in self.save else None)  # save output
#     156 if visualize:
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/nn/modules/head.py:206, in Segment.forward(self, x)
#     203 p = self.proto(x[0])  # mask protos
#     204 bs = p.shape[0]  # batch size
# --> 206 mc = torch.cat([self.cv4[i](x[i]).view(bs, self.nm, -1) for i in range(self.nl)], 2)  # mask coefficients
#     207 x = Detect.forward(self, x)
#     208 if self.training:
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/nn/modules/head.py:206, in <listcomp>(.0)
#     203 p = self.proto(x[0])  # mask protos
#     204 bs = p.shape[0]  # batch size
# --> 206 mc = torch.cat([self.cv4[i](x[i]).view(bs, self.nm, -1) for i in range(self.nl)], 2)  # mask coefficients
#     207 x = Detect.forward(self, x)
#     208 if self.training:
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:91, in Conv.forward_fuse(self, x)
#      81 def forward_fuse(self, x):
#      82     """
#      83     Apply convolution and activation without batch normalization.
#      84
#    (...)
#      89         (torch.Tensor): Output tensor.
#      90     """
# ---> 91     return self.act(self.conv(x))
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/modules/activation.py:432, in SiLU.forward(self, input)
#     431 def forward(self, input: Tensor) -> Tensor:
# --> 432     return F.silu(input, inplace=self.inplace)
#
# File ~/miniconda3/envs/ultra_3.10/lib/python3.10/site-packages/torch/nn/functional.py:2379, in silu(input, inplace)
#    2377     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2378 if inplace:
# -> 2379     return torch._C._nn.silu_(input)
#    2380 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
